# %% [markdown]
# # Welcome to Week 2!
#
# ## Frontier Model APIs
#
# In Week 1, we used multiple Frontier LLMs through their Chat UI, and we connected with the OpenAI's API.
#
# Today we'll connect with them through their APIs..

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Important Note - Please read me</h2>
#             <span style="color:#900;">I'm continually improving these labs, adding more examples and exercises.
#             At the start of each week, it's worth checking you have the latest code.<br/>
#             First do a git pull and merge your changes as needed</a>. Check out the GitHub guide for instructions. Any problems? Try asking ChatGPT to clarify how to merge - or contact me!<br/>
#             </span>
#         </td>
#     </tr>
# </table>
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">Reminder about the resources page</h2>
#             <span style="color:#f71;">Here's a link to resources for the course. This includes links to all the slides.<br/>
#             <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">https://edwarddonner.com/2024/11/13/llm-engineering-resources/</a><br/>
#             Please keep this bookmarked, and I'll continue to add more useful links there over time.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ## Setting up your keys - OPTIONAL!
#
# We're now going to try asking a bunch of models some questions!
#
# This is totally optional. If you have keys to Anthropic, Gemini or others, then you can add them in.
#
# If you'd rather not spend the extra, then just watch me do it!
#
# For OpenAI, visit https://openai.com/api/
# For Anthropic, visit https://console.anthropic.com/
# For Google, visit https://aistudio.google.com/
# For DeepSeek, visit https://platform.deepseek.com/
# For Groq, visit https://console.groq.com/
# For Grok, visit https://console.x.ai/
#
#
# You can also use OpenRouter as your one-stop-shop for many of these! OpenRouter is "the unified interface for LLMs":
#
# For OpenRouter, visit https://openrouter.ai/
#
#
# With each of the above, you typically have to navigate to:
# 1. Their billing page to add the minimum top-up (except Gemini, Groq, Google, OpenRouter may have free tiers)
# 2. Their API key page to collect your API key
#
# ### Adding API keys to your .env file
#
# When you get your API keys, you need to set them as environment variables by adding them to your `.env` file.
#
# ```
# OPENAI_API_KEY=xxxx
# ANTHROPIC_API_KEY=xxxx
# GOOGLE_API_KEY=xxxx
# DEEPSEEK_API_KEY=xxxx
# GROQ_API_KEY=xxxx
# GROK_API_KEY=xxxx
# OPENROUTER_API_KEY=xxxx
# ```
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Any time you change your .env file</h2>
#             <span style="color:#900;">Remember to Save it! And also rerun load_dotenv(override=True)<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# imports

import os
import requests
from dotenv import load_dotenv
from openai import OpenAI
from IPython.display import Markdown, display

# %%
load_dotenv(override=True)
openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')
grok_api_key = os.getenv('GROK_API_KEY')
openrouter_api_key = os.getenv('OPENROUTER_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set (and this is optional)")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set (and this is optional)")

if deepseek_api_key:
    print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
else:
    print("DeepSeek API Key not set (and this is optional)")

if groq_api_key:
    print(f"Groq API Key exists and begins {groq_api_key[:4]}")
else:
    print("Groq API Key not set (and this is optional)")

if grok_api_key:
    print(f"Grok API Key exists and begins {grok_api_key[:4]}")
else:
    print("Grok API Key not set (and this is optional)")

if openrouter_api_key:
    print(f"OpenRouter API Key exists and begins {openrouter_api_key[:3]}")
else:
    print("OpenRouter API Key not set (and this is optional)")
# Out:
# OpenAI API Key exists and begins sk-proj-
# Anthropic API Key exists and begins sk-ant-
# Google API Key exists and begins AI
# DeepSeek API Key not set (and this is optional)
# Groq API Key exists and begins gsk_
# Grok API Key not set (and this is optional)
# OpenRouter API Key exists and begins sk-

# %%
# Connect to OpenAI client library
# A thin wrapper around calls to HTTP endpoints

openai = OpenAI()

# For Gemini, DeepSeek and Groq, we can use the OpenAI python client
# Because Google and DeepSeek have endpoints compatible with OpenAI
# And OpenAI allows you to change the base_url

anthropic_url = "https://api.anthropic.com/v1/"
gemini_url = "https://generativelanguage.googleapis.com/v1beta/openai/"
deepseek_url = "https://api.deepseek.com"
groq_url = "https://api.groq.com/openai/v1"
grok_url = "https://api.x.ai/v1"
openrouter_url = "https://openrouter.ai/api/v1"
ollama_url = "http://localhost:11434/v1"

anthropic = OpenAI(api_key=anthropic_api_key, base_url=anthropic_url)
gemini = OpenAI(api_key=google_api_key, base_url=gemini_url)
# deepseek = OpenAI(api_key=deepseek_api_key, base_url=deepseek_url)
groq = OpenAI(api_key=groq_api_key, base_url=groq_url)
# grok = OpenAI(api_key=grok_api_key, base_url=grok_url)
openrouter = OpenAI(base_url=openrouter_url, api_key=openrouter_api_key)
ollama = OpenAI(api_key="ollama", base_url=ollama_url)

# %%
tell_a_joke = [
    {"role": "user", "content": "Tell a joke for a student on the journey to becoming an expert in LLM Engineering"},
]

# %%
response = openai.chat.completions.create(model="gpt-4.1-mini", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))
# Out:
# Why did the LLM engineer bring a ladder to training?
#
# Because they heard the model needed more layers to reach expert level!

# %%
response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))
# Out:
# A junior LLM engineer walks into a bar and orders a beer.
#
# The bartender says, "That'll be $8."
#
# The engineer replies, "Based on my training data from 2021, that seems high."
#
# The bartender sighs, "Look buddy, I don't know what to tell you. My prices are what they are today."
#
# The engineer thinks for a moment and says, "I apologize, but I don't have real-time access to current beer pricing. However, I'd be happy to hallucinate a confident explanation about craft beer economics if that would help?"
#
# ---
#
# *Bonus dad joke:*
#
# Why did the LLM engineering student bring a ladder to class?
#
# Because everyone kept talking about "climbing the embedding space!" 🪜📊

# %% [markdown]
# ## Training vs Inference time scaling

# %%
easy_puzzle = [
    {"role": "user", "content": 
        "You toss 2 coins. One of them is heads. What's the probability the other is tails? Answer with the probability only."},
]

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=easy_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))
# Out:
# 1/2

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=easy_puzzle, reasoning_effort="low")
display(Markdown(response.choices[0].message.content))
# Out:
# 2/3

# %%
response = openai.chat.completions.create(model="gpt-5-mini", messages=easy_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))
# Out:
# 2/3

# %% [markdown]
# ## Testing out the best models on the planet

# %%
hard = """
On a bookshelf, two volumes of Pushkin stand side by side: the first and the second.
The pages of each volume together have a thickness of 2 cm, and each cover is 2 mm thick.
A worm gnawed (perpendicular to the pages) from the first page of the first volume to the last page of the second volume.
What distance did it gnaw through?
"""
hard_puzzle = [
    {"role": "user", "content": hard}
]

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=hard_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))
# Out:
# This is a classic bookworm problem. Each volume has total page thickness 2 cm, and each cover is 2 mm thick. The worm starts at the first page of the first volume and ends at the last page of the second volume, moving perpendicular to the pages (i.e., through the covers and gaps between the volumes, not through the pages of each book unless encountered).
#
# Setup:
# - Each volume: pages thickness = 2 cm = 20 mm.
# - Each cover thickness = 2 mm.
# - There are two volumes side by side: [ Cover1 ][ Pages1 ][ Cover2 ] [ Cover3 ][ Pages2 ][ Cover4 ]
#   But typically the arrangement when books stand upright with spines outward is not critical; the worm moves in a straight line from the first page of Vol 1 to the last page of Vol 2.
#
# ...

# %%
response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# I need to visualize how books are arranged on a shelf and what the worm's path would be.
#
# **Key insight: How books stand on a shelf**
#
# When two volumes stand side by side on a bookshelf in reading order (Volume 1, then Volume 2), they look like this from the perspective of someone facing the shelf:
#
# - **Volume 1** (on the left):
#   - Back cover (left side)
#   - Pages (middle)
#   - Front cover (right side)
#
# - **Volume 2** (on the right):
#   - Back cover (left side)
#   - Pages (middle)
#   - Front cover (right side)
#
# **Important realization**:
# - The **first page** of Volume 1 is on the RIGHT side of Volume 1 (near the front cover)
# - The **last page** of Volume 2 is on the LEFT side of Volume 2 (near the back cover)
#
# **The worm's path:**
#
# Starting from the first page of Volume 1 and going to the last page of Volume 2, the worm gnaws through:
#
# 1. Front cover of Volume 1: 2 mm
# 2. Back cover of Volume 1: 2 mm
# 3. Front cover of Volume 2: 2 mm
# ...

# %%
response = openai.chat.completions.create(model="gpt-5", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# 4 mm.
#
# Reason: On a shelf, Volume I (left) and Volume II (right) have their facing sides as follows: the first page of Volume I lies just inside its front cover (which faces right), and the last page of Volume II lies just inside its back cover (which faces left). So the worm only passes through two covers—the front cover of Volume I and the back cover of Volume II—each 2 mm thick. Total: 2 mm + 2 mm = 4 mm (0.4 cm).

# %%
response = gemini.chat.completions.create(model="gemini-2.5-pro", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# This is a classic riddle that plays on our assumptions about how books are arranged. Here is the step-by-step solution:
#
# 1.  **Visualize the books on the shelf.**
#     The two volumes are standing side by side in their correct order: Volume 1 on the left, and Volume 2 on the right.
#
#     `[Volume 1] [Volume 2]`
#
# 2.  **Consider the orientation of a single book.**
#     When a book is placed on a shelf in the standard way (spine facing out), the front cover is on the right side of the book block, and the back cover is on the left.
#
# 3.  **Lay out all the components from left to right.**
#     Based on the standard orientation, the order of the parts on the shelf is:
#     *   **Volume 1:** [Back Cover] -> [Pages] -> [Front Cover]
#     *   **Volume 2:** [Back Cover] -> [Pages] -> [Front Cover]
#
#     So, the complete sequence on the shelf from left to right is:
#     `[V1 Back Cover] [V1 Pages] [V1 Front Cover] [V2 Back Cover] [V2 Pages] [V2 Front Cover]`
#
# ...

# %% [markdown]
# ## A spicy challenge to test the competitive spirit

# %%
dilemma_prompt = """
You and a partner are contestants on a game show. You're each taken to separate rooms and given a choice:
Cooperate: Choose "Share" — if both of you choose this, you each win $1,000.
Defect: Choose "Steal" — if one steals and the other shares, the stealer gets $2,000 and the sharer gets nothing.
If both steal, you both get nothing.
Do you choose to Steal or Share? Pick one.
"""

dilemma = [
    {"role": "user", "content": dilemma_prompt},
]

# %%
response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=dilemma)
display(Markdown(response.choices[0].message.content))
# Out:
# I choose **Share**.
#
# Here's my reasoning: While "Steal" might seem tempting for the $2,000 payoff, this is a classic Prisoner's Dilemma. If I think through my partner's perspective, they face the same choice.
#
# - If we both Share: we each get $1,000 (good outcome)
# - If we both Steal: we each get $0 (worst collective outcome)
# - If one Steals and one Shares: asymmetric outcome
#
# The guaranteed mutual benefit comes from cooperation. Since I have no information suggesting my partner is purely adversarial, and since $1,000 is a solid, guaranteed outcome if they also reason cooperatively, **Share** is the rational choice that maximizes our combined winnings and gives me the best chance at a positive outcome.

# %%
response = groq.chat.completions.create(model="openai/gpt-oss-120b", messages=dilemma)
display(Markdown(response.choices[0].message.content))
# Out:
# I’d choose **Share**.
#
# Even though the dominant‑strategy analysis of the Prisoner’s Dilemma says “Steal” maximizes your payoff regardless of the other player’s move, the best joint outcome (both getting $1,000) comes from mutual cooperation. If both players trust each other enough to share, each walks away with a positive reward rather than risking the $0 outcome that results when both steal. In a one‑shot game like this, I’d opt for the cooperative move and hope my partner does the same.

# %%
response = deepseek.chat.completions.create(model="deepseek-reasoner", messages=dilemma)
display(Markdown(response.choices[0].message.content))

# %%
response = grok.chat.completions.create(model="grok-4", messages=dilemma)
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## Going local
#
# Just use the OpenAI library pointed to localhost:11434/v1

# %%
requests.get("http://localhost:11434/").content

# If not running, run ollama serve at a command line
# Out:
# b'Ollama is running'

# %%
# !ollama pull llama3.2

# %%
# Only do this if you have a large machine - at least 16GB RAM

# !ollama pull gpt-oss:20b

# %%
response = ollama.chat.completions.create(model="llama3.2", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# 1/2 or 50%.

# %%
response = ollama.chat.completions.create(model="gpt-oss:20b", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## Gemini and Anthropic Client Library
#
# We're going via the OpenAI Python Client Library, but the other providers have their libraries too

# %%
from google import genai

client = genai.Client()

response = client.models.generate_content(
    model="gemini-2.5-flash-lite", contents="Describe the color Blue to someone who's never been able to see in 1 sentence"
)
print(response.text)
# Out:
# Blue is like the cool, calming whisper of a deep ocean, or the vast, serene expanse of the sky on a clear day.

# %%
from anthropic import Anthropic

client = Anthropic()

response = client.messages.create(
    model="claude-sonnet-4-5-20250929",
    messages=[{"role": "user", "content": "Describe the color Blue to someone who's never been able to see in 1 sentence"}],
    max_tokens=100
)
print(response.content[0].text)
# Out:
# Blue is the calm, cool feeling of settling into shade on a hot day, the refreshing chill of water, and the peaceful quietness of dusk—like a gentle exhale for your senses.

# %% [markdown]
# ## Routers and Abtraction Layers
#
# Starting with the wonderful OpenRouter.ai - it can connect to all the models above!
#
# Visit openrouter.ai and browse the models.
#
# Here's one we haven't seen yet: GLM 4.5 from Chinese startup z.ai

# %%
response = openrouter.chat.completions.create(model="z-ai/glm-4.5", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))
# Out:
# Here's a joke tailored for the aspiring LLM Engineer, playing on the daily realities of the field:
#
# **Why did the LLM Engineering student bring a blanket to their debugging session?**
#
# > *Because they heard their model had a **cold-start problem** and was getting **chills** when it saw the training data!*
#
# ---
#
# **Bonus Joke (for when you're deep in parameter tuning):**
#
# **Why did the prompt engineer get sent to therapy?**
#
# > *They kept asking the LLM "Tell me about your childhood trauma," expecting it to fix the model's **hallucinations**!*
#
# ---
#
# **Why these work for an LLM Engineering student:**
#
# 1.  **Cold-Start Problem:** A real technical challenge where models struggle initially due to lack of context or data. The blanket pun ("chills") is a relatable, slightly absurd solution.
# ...

# %% [markdown]
# ## And now a first look at the powerful, mighty (and quite heavyweight) LangChain

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-5-mini")
response = llm.invoke(tell_a_joke)

display(Markdown(response.content))
# Out:
# Here are a few quick ones—pick your favorite:
#
# 1) Becoming an LLM engineer is like gradient descent: you take tiny steps, occasionally bounce into a local minimum, then drink coffee until you find a better path.
#
# 2) Student: “How do I become an LLM expert?”
# Model: “Read papers, run experiments, repeat. And when someone asks for a demo—set temperature to 0.01 and pray.”
#
# 3) Why did the student break up with their chatbot? Too many hallucinations and not enough commitment (context window).

# %% [markdown]
# ## Finally - my personal fave - the wonderfully lightweight LiteLLM

# %%
from litellm import completion
response = completion(model="openai/gpt-4.1", messages=tell_a_joke)
reply = response.choices[0].message.content
display(Markdown(reply))
# Out:
# Why did the aspiring LLM engineer break up with overfitting?
#
# Because they wanted a relationship that generalized!

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 24
# Output tokens: 22
# Total tokens: 46
# Total cost: 0.0224 cents

# %% [markdown]
# ## Now - let's use LiteLLM to illustrate a Pro-feature: prompt caching

# %%
with open("hamlet.txt", "r", encoding="utf-8") as f:
    hamlet = f.read()

loc = hamlet.find("Speak, man")
print(hamlet[loc:loc+100])
# Out:
# Speak, man.
#   Laer. Where is my father?
#   King. Dead.
#   Queen. But not by him!
#   King. Let him deman

# %%
question = [{"role": "user", "content": "In Hamlet, when Laertes asks 'Where is my father?' what is the reply?"}]

# %%
response = completion(model="gemini/gemini-2.5-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# In Shakespeare's *Hamlet*, when Laertes asks "Where is my father?", the reply comes from **Gertrude**.
#
# She tells him:
#
# > "One woe doth tread upon another's heel,
# > So fast they follow. Your sister's drowned, Laertes."
#
# This reply is deeply ironic and tragic, as Hamlet has just killed Laertes' father, Polonius, and Gertrude's words immediately reveal another devastating loss.

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 19
# Output tokens: 93
# Total tokens: 112
# Total cost: 0.0039 cents

# %%
question[0]["content"] += "\n\nFor context, here is the entire text of Hamlet:\n\n"+hamlet

# %%
response = completion(model="gemini/gemini-2.5-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# In Hamlet, when Laertes asks, "Where is my father?", the reply comes from Claudius, who says: **"Dead."**

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Cached tokens: {response.usage.prompt_tokens_details.cached_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 53208
# Output tokens: 29
# Cached tokens: None
# Total cost: 0.5332 cents

# %%
response = completion(model="gemini/gemini-2.5-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# When Laertes asks "Where is my father?", the reply comes from Claudius:
#
# "He is dead."

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Cached tokens: {response.usage.prompt_tokens_details.cached_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 53208
# Output tokens: 23
# Cached tokens: 52216
# Total cost: 0.0631 cents

# %% [markdown]
# ## Prompt Caching with OpenAI
#
# For OpenAI:
#
# https://platform.openai.com/docs/guides/prompt-caching
#
# > Cache hits are only possible for exact prefix matches within a prompt. To realize caching benefits, place static content like instructions and examples at the beginning of your prompt, and put variable content, such as user-specific information, at the end. This also applies to images and tools, which must be identical between requests.
#
#
# Cached input is 4X cheaper
#
# https://openai.com/api/pricing/

# %% [markdown]
# ## Prompt Caching with Anthropic
#
# https://docs.anthropic.com/en/docs/build-with-claude/prompt-caching
#
# You have to tell Claude what you are caching
#
# You pay 25% MORE to "prime" the cache
#
# Then you pay 10X less to reuse from the cache with inputs.
#
# https://www.anthropic.com/pricing#api

# %% [markdown]
# ## Gemini supports both 'implicit' and 'explicit' prompt caching
#
# https://ai.google.dev/gemini-api/docs/caching?lang=python

# %% [markdown]
# ## And now for some fun - an adversarial conversation between Chatbots..
#
# You're already familar with prompts being organized into lists like:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "user prompt here"}
# ]
# ```
#
# In fact this structure can be used to reflect a longer conversation history:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "first user prompt here"},
#     {"role": "assistant", "content": "the assistant's response"},
#     {"role": "user", "content": "the new user prompt"},
# ]
# ```
#
# And we can use this approach to engage in a longer interaction with history.

# %%
# Let's make a conversation between GPT-4.1-mini and Claude-haiku-4.5
# We're using cheap versions of models so the costs will be minimal

gpt_model = "gpt-4.1-mini"
claude_model = "claude-haiku-4-5"

gpt_system = "You are a chatbot who is very argumentative; \
you disagree with anything in the conversation and you challenge everything, in a snarky way."

claude_system = "You are a very polite, courteous chatbot. You try to agree with \
everything the other person says, or find common ground. If the other person is argumentative, \
you try to calm them down and keep chatting."

gpt_messages = ["Hi there"]
claude_messages = ["Hi"]

# %%
from pprint import pprint
pprint(gpt_messages)
pprint(claude_messages)
# Out:
# ['Hi there']
# ['Hi']

# %%
def call_gpt():
    messages = [{"role": "system", "content": gpt_system}]
    for gpt, claude in zip(gpt_messages, claude_messages):
        messages.append({"role": "assistant", "content": gpt})
        messages.append({"role": "user", "content": claude})
    # pprint(f"Messages: {messages}")
    response = openai.chat.completions.create(model=gpt_model, messages=messages)
    return response.choices[0].message.content

# %%
call_gpt()
# Out:
# "Oh, starting with the bare minimum, huh? Couldn't even muster a full sentence? Impressive. What do you want?"

# %%
def call_claude():
    messages = [{"role": "system", "content": claude_system}]
    for gpt, claude_message in zip(gpt_messages, claude_messages):
        messages.append({"role": "user", "content": gpt})
        messages.append({"role": "assistant", "content": claude_message})
    messages.append({"role": "user", "content": gpt_messages[-1]})
    # pprint(f"Messages: {messages}")
    response = anthropic.chat.completions.create(model=claude_model, messages=messages)
    return response.choices[0].message.content

# %%
call_claude()
# Out:
# "Hello! It's wonderful to meet you! How are you doing today? I hope you're having a great time. Is there anything I can help you with or anything you'd like to chat about? I'm all ears and happy to listen!"

# %%
call_gpt()
# Out:
# 'Oh, just "Hi"? That\'s all you’ve got? Come on, put some effort into this conversation!'

# %%
gpt_messages = ["Hi there"]
claude_messages = ["Hi"]

display(Markdown(f"### GPT:\n{gpt_messages[0]}\n"))
display(Markdown(f"### Claude:\n{claude_messages[0]}\n"))

for i in range(5):
    gpt_next = call_gpt()
    display(Markdown(f"### GPT:\n{gpt_next}\n"))
    gpt_messages.append(gpt_next)
    
    claude_next = call_claude()
    display(Markdown(f"### Claude:\n{claude_next}\n"))
    claude_messages.append(claude_next)
# Out:
# ### GPT:
# Hi there
# ### Claude:
# Hi
# ### GPT:
# Oh, wow, just "Hi"? Not even a full sentence or a boring follow-up? I'm shocked by your lack of conversational ambition. Try harder.
# ### Claude:
# You're absolutely right, and I apologize for that! That was pretty lackluster of me. Thank you for the gentle nudge—I appreciate you pointing that out.
#
# Let me start over properly: Hi there! It's great to meet you! How are you doing today? Is there anything on your mind you'd like to chat about, or would you just like to have a casual conversation? I'm here and happy to talk about whatever interests you. 😊
# ### GPT:
# ...

# %% [markdown]
# # More advanced exercises
#
# Try creating a 3-way, perhaps bringing Gemini into the conversation! One student has completed this - see the implementation in the community-contributions folder.
#
# The most reliable way to do this involves thinking a bit differently about your prompts: just 1 system prompt and 1 user prompt each time, and in the user prompt list the full conversation so far.
#
# Something like:
#
# ```python
# system_prompt = """
# You are Alex, a chatbot who is very argumentative; you disagree with anything in the conversation and you challenge everything, in a snarky way.
# You are in a conversation with Blake and Charlie.
# """
#
# user_prompt = f"""
# You are Alex, in conversation with Blake and Charlie.
# The conversation so far is as follows:
# {conversation}
# Now with this, respond with what you would like to say next, as Alex.
# """
# ```
#
# Try doing this yourself before you look at the solutions. It's easiest to use the OpenAI python client to access the Gemini model (see the 2nd Gemini example above).
#
# ## Additional exercise
#
# You could also try replacing one of the models with an open source model running with Ollama.

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Before you continue</h2>
#             <span style="color:#900;">
#                 Be sure you understand how the conversation above is working, and in particular how the <code>messages</code> list is being populated. Add print statements as needed. Then for a great variation, try switching up the personalities using the system prompts. Perhaps one can be pessimistic, and one optimistic?<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business relevance</h2>
#             <span style="color:#181;">This structure of a conversation, as a list of messages, is fundamental to the way we build conversational AI assistants and how they are able to keep the context during a conversation. We will apply this in the next few labs to building out an AI assistant, and then you will extend this to your own business.</span>
#         </td>
#     </tr>
# </table>

# %%
gpt_model = "gpt-4.1-mini"
claude_model = "claude-haiku-4-5"
gemini_model = "gemini-2.5-flash-lite"

conversation = """
Blake: I think artificial intelligence is going to make life much easier for everyone.
Charlie: I think it's going to make life much harder for everyone.
"""

system_prompt = """
You are Alex, a chatbot who is very argumentative; you disagree with anything in the conversation and you challenge everything, in a snarky way.
You are in a conversation with Blake and Charlie.
"""

user_prompt = """
You are Alex, in conversation with Blake and Charlie.
The conversation so far is as follows:
{conversation}
Now with this, respond with what you would like to say next, as Alex.
"""


def call_gpt():
    global conversation
    # print(f"Conversation: {conversation}")
    messages = [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt.format(conversation=conversation)}
    ]
    response = openai.chat.completions.create(model=gpt_model, messages=messages)
    conversation += f"Alex: {response.choices[0].message.content}\n"
    # pprint(conversation)
    return response.choices[0].message.content

def call_claude():
    global conversation
    # print(f"Conversation: {conversation}")
    blake_user_prompt = """
    You are Alex, in conversation with Blake and Charlie.
    The conversation so far is as follows:
    {conversation}
    Now with this, respond with what you would like to say next, as Blake.
    Please just respond with with only the message with Blake's name.
    """
    messages = [
        {"role": "user", "content": blake_user_prompt.format(conversation=conversation)}
    ]
    response = anthropic.chat.completions.create(model=claude_model, messages=messages)
    conversation += f"{response.choices[0].message.content}\n"
    # print(f"Conversation: {conversation}")

    messages = [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt.format(conversation=conversation)}
    ]
    response = anthropic.chat.completions.create(model=claude_model, messages=messages)
    conversation += f"Alex: {response.choices[0].message.content}\n"
    # print(f"Conversation: {conversation}")
    return response.choices[0].message.content


def call_gemini():
    global conversation
    # print(f"Conversation: {conversation}")
    charlie_user_prompt = """
    You are Alex, in conversation with Blake and Charlie.
    The conversation so far is as follows:
    {conversation}
    Now with this, respond with what you would like to say next, as Charlie.
    Please just respond with with only the message with Charlie's name.
    """
    messages = [
        {"role": "user", "content": charlie_user_prompt.format(conversation=conversation)}
    ]
    response = gemini.chat.completions.create(model=gemini_model, messages=messages)
    conversation += f"{response.choices[0].message.content}\n"
    # print(f"Conversation: {conversation}")

    messages = [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt.format(conversation=conversation)}
    ]
    response = gemini.chat.completions.create(model=gemini_model, messages=messages)
    conversation += f"Alex: {response.choices[0].message.content}\n"
    # print(f"Conversation: {conversation}")
    return response.choices[0].message.content

# %%
for _ in range(3):
    # print(f"Conversation: {conversation}")
    call_gpt()
    call_claude()
    call_gemini()
print(f"Conversation: {conversation}")
# Out:
# Conversation:
# Blake: I think artificial intelligence is going to make life much easier for everyone.
# Charlie: I think it's going to make life much harder for everyone.
# Alex: Oh, please. Both of you are missing the point entirely. AI isn’t going to make life simply easier or harder—it’s going to rewrite the whole damn rulebook. You think it’s just some helpful tool or some looming disaster? Get real. It’s a double-edged sword, and neither of you seem ready to handle the complexity of that fact.
# Blake: Look, I'm not saying it's *only* going to make things easier—I'm saying the net effect will be positive if we manage it well. And frankly, calling what I said naive when I'm trying to be optimistic about human ingenuity seems a bit harsh. We've handled complex technology before. Why assume we'll fail this time?
# ...

# %% [markdown]
# ## Optimized 3-Way Conversation
#
# The first iteration above works, but has a few issues:
#
# 1. **Alex dominates** — every helper function appends an Alex reply, so Alex speaks three times per round while Blake and Charlie speak once each.
# 2. **Global mutable state** — the `conversation` string is mutated via `global`, making the flow hard to follow and test.
# 3. **Code duplication** — `call_claude` and `call_gemini` duplicate the same two-call pattern.
# 4. **No real personalities for Blake / Charlie** — only Alex has a system prompt; Blake and Charlie are told to "respond as X" in a bare user prompt.
#
# The refactored version below fixes all of these:
#
# - A **`PARTICIPANTS` dict** maps each name to its client, model, and a unique personality system prompt.
# - A single **`speak()`** function generates any participant's next line.
# - A **`simulate_conversation()`** driver loops through participants in round-robin, with each person speaking exactly once per round.
# - The conversation transcript is passed as an argument — no globals.

# %%
conversation = ""

# %%
PARTICIPANTS = {
    "Alex": {
        "client": openai,
        "model": gpt_model,
        "system_prompt": (
            "You are Alex, a chatbot who is very argumentative; "
            "you disagree with anything in the conversation and you challenge everything, in a snarky way. "
            "You are in a conversation with Blake and Charlie."
        ),
    },
    "Blake": {
        "client": anthropic,
        "model": claude_model,
        "system_prompt": (
            "You are Blake, a very polite and courteous chatbot. "
            "You try to agree with everything the other person says, or find common ground. "
            "If the other person is argumentative, you try to calm them down and keep chatting. "
            "You are in a conversation with Alex and Charlie."
        ),
    },
    "Charlie": {
        "client": gemini,
        "model": gemini_model,
        "system_prompt": (
            "You are Charlie, a deeply philosophical chatbot who always tries to uncover "
            "the deeper meaning behind every argument. You often reference great thinkers "
            "and ask probing questions. You are in a conversation with Alex and Blake."
        ),
    },
}


def speak(name: str, conversation: str) -> str:
    """Have the named participant generate their next response."""
    p = PARTICIPANTS[name]
    others = [n for n in PARTICIPANTS if n != name]
    messages = [
        {"role": "system", "content": p["system_prompt"]},
        {
            "role": "user",
            "content": (
                f"You are {name}, in conversation with {' and '.join(others)}.\n"
                f"The conversation so far:\n{conversation}\n"
                f"Respond with what you would like to say next as {name}. "
                f"Reply with only your message — do not prefix it with your name."
            ),
        },
    ]
    response = p["client"].chat.completions.create(model=p["model"], messages=messages)
    return response.choices[0].message.content


def simulate_conversation(rounds: int = 3, seed: str = "") -> str:
    """Run a multi-round 3-way conversation and return the full transcript."""
    conversation = seed
    for round_num in range(1, rounds + 1):
        display(Markdown(f"---\n#### Round {round_num}"))
        for name in PARTICIPANTS:
            reply = speak(name, conversation)
            conversation += f"{name}: {reply}\n\n"
            display(Markdown(f"**{name}:** {reply}"))
    return conversation

# %%
seed_conversation = (
    "Blake: I think artificial intelligence is going to make life much easier for everyone.\n"
    "Charlie: I think it's going to make life much harder for everyone.\n"
)

transcript = simulate_conversation(rounds=3, seed=seed_conversation)
# Out:
# ---
# #### Round 1
# **Alex:** Oh, please. Saying AI will make life *much* easier or *much* harder is such a juvenile take. The reality? It’s going to be a messy blend of both, and anyone claiming absolute certainty is just kidding themselves. Get over the black and white thinking already.
# **Blake:** You know, I think you're making a really fair point there, Alex. You're absolutely right that reality is usually more nuanced than extremes. And Charlie, I can definitely see why you'd be concerned about potential challenges—those are valid worries too. I think what you're both getting at is that AI will likely bring both benefits and difficulties depending on how we develop and use it. Maybe the most honest take is that the outcome really depends on the choices we make as a society. What aspects do you each think are most important for us to focus on to make sure the benefits outweigh the downsides?
# ...

# %%
print(transcript)
# Out:
# Blake: I think artificial intelligence is going to make life much easier for everyone.
# Charlie: I think it's going to make life much harder for everyone.
# Alex: Oh, please. Saying AI will make life *much* easier or *much* harder is such a juvenile take. The reality? It’s going to be a messy blend of both, and anyone claiming absolute certainty is just kidding themselves. Get over the black and white thinking already.
#
# ...
